# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
from statistics import mean
import json, re, ast

load_dotenv(override=True)

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
def generate_dataset():
    prompt = f"""
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {{
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": {{
            "required_elements": [],
            "validation_rules": [],
            "edge_cases": [],
            "disallowed": []
        }}
    }},
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Solution criteria:
<solution_criteria>
{test_case["solution_criteria"]}
</solution_criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
"""

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean(result["score"] for result in results)
    print("[Average Score]:", average_score)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# [Average Score]: 6.833333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\n\nlambda_config = {\n    \"FunctionName\": \"S3EventProcessor\",\n    \"Runtime\": \"python3.11\",\n    \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-s3-execution-role\",\n    \"Handler\": \"index.handler\",\n    \"Timeout\": 60,\n    \"MemorySize\": 256,\n    \"Environment\": {\n        \"Variables\": {\n            \"S3_BUCKET_NAME\": \"my-source-bucket\",\n            \"CLOUDWATCH_LOG_GROUP\": \"/aws/lambda/s3-event-processor\",\n            \"TIMEOUT_SECONDS\": \"60\",\n            \"LOG_LEVEL\": \"INFO\"\n        }\n    },\n    \"Code\": {\n        \"S3Bucket\": \"my-lambda-code-bucket\",\n        \"S3Key\": \"functions/s3-event-processor.zip\"\n    },\n    \"Events\": {\n        \"S3Event\": {\n            \"Type\": \"S3\",\n            \"Properties\": {\n                \"Bucket\": \"my-source-bucket\",\n                \"Events\": [\"s3:ObjectCreated:*\", \"s3:ObjectRemoved:*\"],\n                \"Filter\": {\n                    \"Key\": {\n                        \"FilterRules\": [\n                            {\n                                \"Name\": \"prefix\",\n                                \"Value\": \"uploads/\"\n                            }\n                        ]\n                    }\n                }\n            }\n        }\n    },\n    \"LoggingConfig\": {\n        \"LogGroup\": \"/aws/lambda/s3-event-processor\",\n        \"LogFormat\": \"JSON\"\n    },\n    \"EphemeralStorage\": {\n        \"Size\": 512\n    }\n}\n\nprint(json.dumps(lambda_config, indent=2))\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events. Include environment variables for the S3 bucket name, CloudWatch log group, and timeout settings.",
#       "format": "json",
#       "solution_criteria": {
#         "required_elements": [
#           "FunctionName",
#           "Runtime",
#           "Handler",
#           "Environment.Variables with S3_BUCKET, LOG_GROUP, and TIMEOUT",
#           "Timeout value",
#           "Role ARN structure"
#         ],
#         "validation_rules": [
#           "FunctionName must be a non-empty string",
#           "Runtime must be a valid Lambda runtime (e.g., python3.11, nodejs18.x)",
#           "Timeout must be an integer between 1 and 900",
#           "Environment variables must be in key-value pairs"
#         ],
#         "edge_cases": [
#           "Handle empty or null environment variables",
#           "Support various valid Lambda runtimes"
#         ],
#         "disallowed": [
#           "Invalid runtime names",
#           "Timeout values outside valid range",
#           "Malformed IAM role ARNs"
#         ]
#       }
#     },
#     "score": 3.5,
#     "reasoning": "The solution successfully meets all required criteria and demonstrates good AWS practices with comprehensive configuration options. However, it has a critical inconsistency: the 'Events' section uses declarative event source mapping syntax that doesn't align with AWS Lambda CreateFunction API, which is what the rest of the configuration represents. Additionally, the code lacks input validation and documentation for customizing placeholder values. These are notable but not critical issues since the core requirements are satisfied."
#   },
#   {
#     "output": "\nimport re\n\ndef validate_s3_bucket_name(bucket_name: str) -> bool:\n    \"\"\"\n    Validates an AWS S3 bucket name against AWS naming rules.\n    \n    Rules:\n    - Bucket names must be between 3 and 63 characters long\n    - Bucket names can consist only of lowercase letters, numbers, dots (.), and hyphens (-)\n    - Bucket names must start and end with a letter or number\n    - Bucket names must not contain consecutive dots\n    - Bucket names must not be formatted as an IP address (e.g., 192.168.5.4)\n    \"\"\"\n    if not isinstance(bucket_name, str):\n        return False\n    \n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    if not re.match(r'^[a-z0-9]([a-z0-9.-]*[a-z0-9])?$', bucket_name):\n        return False\n    \n    if '..' in bucket_name:\n        return False\n    \n    if re.match(r'^(\\d{1,3}\\.){3}\\d{1,3}$', bucket_name):\n        return False\n    \n    return True\n\n\n# Test cases\ntest_cases = [\n    (\"my-bucket\", True),\n    (\"mybucket123\", True),\n    (\"my.bucket\", True),\n    (\"a\", False),\n    (\"ab\", False),\n    (\"abc\", True),\n    (\"my-bucket-\", False),\n    (\"-my-bucket\", False),\n    (\"my..bucket\", False),\n    (\"192.168.1.1\", False),\n    (\"My-Bucket\", False),\n    (\"my_bucket\", False),\n    (\"my bucket\", False),\n    (\"a\" * 64, False),\n    (\"a\" * 63, True),\n    (\"my-bucket.example\", True),\n]\n\nfor bucket_name, expected in test_cases:\n    result = validate_s3_bucket_name(bucket_name)\n    status = \"\u2713\" if result == expected else \"\u2717\"\n    print(f\"{status} {bucket_name}: {result} (expected {expected})\")\n",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS S3 bucket name against AWS naming rules. The function should accept a bucket name string and return True if valid, False otherwise.",
#       "format": "python",
#       "solution_criteria": {
#         "required_elements": [
#           "Function definition",
#           "Input parameter for bucket name",
#           "Return boolean value"
#         ],
#         "validation_rules": [
#           "Bucket name must be 3-63 characters long",
#           "Must start and end with lowercase letter or number",
#           "Can only contain lowercase letters, numbers, and hyphens",
#           "Cannot be formatted as an IP address (e.g., 192.168.1.1)",
#           "Cannot contain consecutive hyphens"
#         ],
#         "edge_cases": [
#           "Empty string input",
#           "Bucket names at boundary lengths (3, 63 characters)",
#           "Names with uppercase letters",
#           "Names ending with hyphen"
#         ],
#         "disallowed": [
#           "Multiple function definitions",
#           "External library dependencies beyond standard library",
#           "Hardcoded bucket names"
#         ]
#       }
#     },
#     "score": 8.5,
#     "reasoning": "The solution successfully addresses most core requirements and implements the main validation rules correctly with good code quality. However, it has a notable oversight: consecutive hyphens should be disallowed per AWS rules but aren't checked. The solution would fail validation against actual AWS S3 naming constraints for inputs like 'my--bucket' (which AWS rejects but the function would accept). The regex pattern itself is functional but could be more explicit. The test cases are comprehensive but don't cover the consecutive hyphen edge case, which is documented in the criteria as 'Cannot contain consecutive hyphens'."
#   },
#   {
#     "output": "\narn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-_]+\n",
#     "test_case": {
#       "task": "Create a regular expression that matches valid AWS IAM role ARNs in the format: arn:aws:iam::account-id:role/role-name where account-id is 12 digits and role-name contains alphanumeric characters, hyphens, and underscores.",
#       "format": "regex",
#       "solution_criteria": {
#         "required_elements": [
#           "Match 'arn:aws:iam::' prefix",
#           "Match exactly 12-digit account ID",
#           "Match 'role/' literal",
#           "Match role name with allowed characters"
#         ],
#         "validation_rules": [
#           "Account ID must be exactly 12 digits",
#           "Role name must contain only alphanumeric characters, hyphens, and underscores",
#           "Role name must be at least 1 character long"
#         ],
#         "edge_cases": [
#           "Minimum length role names (1 character)",
#           "Role names with multiple consecutive special characters",
#           "Account ID with leading zeros"
#         ],
#         "disallowed": [
#           "Matching invalid separators or prefixes",
#           "Allowing role names with invalid characters (dots, spaces, special chars)",
#           "Accepting account IDs with incorrect digit count"
#         ]
#       }
#     },
#     "score": 8.5,
#     "reasoning": "The regex correctly implements all core matching requirements: proper prefix, 12-digit account ID validation, role/ literal, and character class for role names. It handles edge cases like leading zeros in account IDs and minimum-length role names appropriately. However, it lacks anchoring which violates best practices for ARN validation - without ^ and $, it would match 'prefix-arn:aws:iam::123456789012:role/valid-suffix' incorrectly. For production use in AWS tooling, anchors are essential to prevent false positives and ensure strict validation."
#   }
# ]
