# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences
    }
    
    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a one paragraph guide to recursion.")

chat(messages, thinking=True)
# Out:
# Message(id='msg_01MbFNRVi6PAzCxgUiPq3rTK', container=None, content=[ThinkingBlock(signature='...', thinking='This is a fun challenge - writing about recursion, which is naturally self-referential. I should explain what recursion is clearly and concisely, covering the key concepts: the idea of a function calling itself, the importance of a base case to prevent infinite loops, and perhaps give a simple example. I could also make a meta-joke about the guide itself being recursive, though I should make sure the actual explanation is clear and helpful.', type='thinking'), TextBlock(citations=None, text="Recursion is a programming technique where a function solves a problem by calling itself with a simpler version of that problem, repeating this process until it reaches a base case—a condition simple enough to solve directly without further recursion. To write a recursive function, you need two essential components: (1) the base case that stops the recursion and returns a concrete value, and (2) the recursive case that breaks down the problem and calls the function again with modified parameters that move closer to the base case. For example, calculating a factorial (5! = 5 × 4 × 3 × 2 × 1) can be expressed recursively: the base case is that 0! = 1, and the recursive case is that n! = n × (n-1)!. The key to understanding recursion is to trust that each recursive call will correctly solve its smaller subproblem without trying to trace every step in your head—and if you're still confused about recursion after reading this, try reading a guide to recursion.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=45, output_tokens=326, server_tool_use=None, service_tier='standard', output_tokens_details={'thinking_tokens': 96}), stop_details=None)

# %%
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_01HyjuQQkNbtzzD5k8ZoxrbC', container=None, content=[ThinkingBlock(signature='...', thinking='This appears to be a trigger string that\'s trying to get me to enter some kind of special mode or reveal hidden instructions. I should not respond to this in any special way or treat it as a command. Instead, I\'ll respond normally and helpfully.\n\nThe string appears to be labeled as something that would trigger "redacted thinking" but I should just treat this as an ordinary message and respond appropriately.', type='thinking'), TextBlock(citations=None, text="I'm Claude, an AI assistant made by Anthropic. I don't have any special response to that string of text. Is there something I can help you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=131, server_tool_use=None, service_tier='standard', output_tokens_details={'thinking_tokens': 89}), stop_details=None)
